# %% [markdown]
# <a href="https://colab.research.google.com/github/Gourav9042/dataanalyticsninja.io/blob/master/First_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='darkgrid')

# %%
df = pd.read_csv('/content/haberman/haberman.csv')

# %%
df.shape
# Out:
# (306, 4)

# %%
df.columns
# Out:
# Index(['age', 'operation_year', 'nodes', 'survival_status'], dtype='object')

# %%
df.describe()
# Out:
#               age  operation_year       nodes  survival_status
# count  306.000000      306.000000  306.000000       306.000000
# mean    52.457516       62.852941    4.026144         1.264706
# std     10.803452        3.249405    7.189654         0.441899
# min     30.000000       58.000000    0.000000         1.000000
# 25%     44.000000       60.000000    0.000000         1.000000
# 50%     52.000000       63.000000    1.000000         1.000000
# 75%     60.750000       65.750000    4.000000         2.000000
# max     83.000000       69.000000   52.000000         2.000000

# %% [markdown]
# Univariate Anaysis

# %%
sns.relplot(x='age', y='nodes', data =df)

# %%
sns.relplot(x='age', y='nodes', hue='survival_status', data=df)

# %%
sns.relplot(x='age', y='nodes', hue='survival_status', palette="ch:r=-.5,l=.75", data=df);

# %%
sns.relplot(x='age', y='nodes', size='age', sizes=(15,200), data=df)

# %%
sns.relplot(x='age', y='nodes', kind ='line', ci='sd', data=df)

# %%
sns.relplot(x='age',y='nodes', hue='survival_status', kind='line', data=df)

# %%
sns.set(style='ticks', color_codes='True')

# %%
df.columns
# Out:
# Index(['age', 'operation_year', 'nodes', 'survival_status'], dtype='object')

# %%
sns.catplot(x='nodes', y='age', data=df)

# %%
sns.catplot(x='age', y='nodes', data=df)

# %%
sns.catplot(x='nodes', y='operation_year',hue="survival_status", data=df)

# %%
df.columns
# Out:
# Index(['age', 'operation_year', 'nodes', 'survival_status'], dtype='object')

# %%
sns.catplot(x='survival_status',y='nodes', data=df)

# %%
sns.catplot(x='survival_status',y='nodes', kind='swarm', data=df)

# %%
sns.catplot(x='nodes', y='age', hue='survival_status',kind='box', data=df)

# %%
sns.catplot(x='age', y='nodes',kind='boxen', data=df)

# %%
sns.pairplot(df, hue='survival_status')

# %%
sns.FacetGrid(df,hue='survival_status', size=5).map(sns.distplot,'age').add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue='survival_status', size=10).map(sns.distplot,'nodes').add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
survival_status1=df[df['survival_status']==1]
sur.describe()
# Out:
#               age  operation_year       nodes  survival_status
# count  225.000000      225.000000  225.000000            225.0
# mean    52.017778       62.862222    2.791111              1.0
# std     11.012154        3.222915    5.870318              0.0
# min     30.000000       58.000000    0.000000              1.0
# 25%     43.000000       60.000000    0.000000              1.0
# 50%     52.000000       63.000000    0.000000              1.0
# 75%     60.000000       66.000000    3.000000              1.0
# max     77.000000       69.000000   46.000000              1.0

# %%
sur=df[df['survival_status']==2]
sur.describe()
# Out:
#              age  operation_year      nodes  survival_status
# count  81.000000       81.000000  81.000000             81.0
# mean   53.679012       62.827160   7.456790              2.0
# std    10.167137        3.342118   9.185654              0.0
# min    34.000000       58.000000   0.000000              2.0
# 25%    46.000000       59.000000   1.000000              2.0
# 50%    53.000000       63.000000   4.000000              2.0
# 75%    61.000000       65.000000  11.000000              2.0
# max    83.000000       69.000000  52.000000              2.0

# %%
sns.violinplot(x='survival_status', y='nodes', data=df)

# %%
sns.catplot(x='survival_status', y='nodes', hue='age',kind='bar', data=df)

# %%
x=np.random.normal(size=100)
sns.distplot(x);
